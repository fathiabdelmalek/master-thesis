# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from scipy.stats import mode
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy
from keras.metrics import Precision, Recall

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import pyttsx3  # require to install espeak (sudo apt/dnf install espeak)
# Out:
# 2023-04-14 03:46:36.065576: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-14 03:46:36.240657: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-14 03:46:36.242180: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-14 03:46:40.089989: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv('../data/all.csv')
X = df[['flex_1', 'flex_2', 'flex_3', 'flex_4', 'flex_5', 'GYRx', 'GYRy', 'GYRz', 'ACCx', 'ACCy', 'ACCz']].values
labels = df.iloc[:, -1]
label_dict = {label: i for i, label in enumerate(sorted(set(labels)))}
y = np.array([label_dict[label] for label in labels])
y = to_categorical(y, num_classes=len(label_dict))

print(label_dict)

print(X.shape, y.shape)
X = np.reshape(X, (X.shape[0]//150, 150, X.shape[1]))
y = np.reshape(y, (y.shape[0]//150, 150, y.shape[1]))
print(X.shape, y.shape)
# Out:
# {'a': 0, 'b': 1, 'bad': 2, 'c': 3, 'd': 4, 'deaf': 5, 'e': 6, 'f': 7, 'fine': 8, 'g': 9, 'good': 10, 'goodbye': 11, 'h': 12, 'hello': 13, 'hungry': 14, 'i': 15, 'j': 16, 'k': 17, 'l': 18, 'm': 19, 'me': 20, 'n': 21, 'no': 22, 'o': 23, 'p': 24, 'please': 25, 'q': 26, 'r': 27, 's': 28, 'sorry': 29, 't': 30, 'thankyou': 31, 'u': 32, 'v': 33, 'w': 34, 'x': 35, 'y': 36, 'yes': 37, 'you': 38, 'z': 39}
# (1500000, 11) (1500000, 40)
# (10000, 150, 11) (10000, 150, 40)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
# Out:
# (8100, 150, 11) (1000, 150, 11) (900, 150, 11)
# (8100, 150, 40) (1000, 150, 40) (900, 150, 40)

# %%
model = Sequential()
model.add(LSTM(units=64, input_shape=(150, 11), return_sequences=True))
model.add(Dense(units=len(label_dict), activation='softmax'))
model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['accuracy', Precision(), Recall()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32)
# Out:
# 2023-04-14 03:47:07.366835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-14 03:47:07.375072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-14 03:47:07.377322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-14 03:47:07.785093: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 194400000 exceeds 10% of free system memory.
# Epoch 1/50
# 2023-04-14 03:47:08.595287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-14 03:47:08.598670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-14 03:47:08.601564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-14 03:47:10.172684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-14 03:47:10.176352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-14 03:47:10.179306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 254/254 [==============================] - ETA: 0s - loss: 2.7826 - accuracy: 0.2821 - precision: 0.9998 - recall: 0.0036
# 2023-04-14 03:47:32.565664: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-14 03:47:32.570631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-14 03:47:32.572954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 254/254 [==============================] - 26s 83ms/step - loss: 2.7826 - accuracy: 0.2821 - precision: 0.9998 - recall: 0.0036 - val_loss: 1.9557 - val_accuracy: 0.4881 - val_precision: 0.9193 - val_recall: 0.0312
# Epoch 2/50
# 254/254 [==============================] - 20s 77ms/step - loss: 1.5857 - accuracy: 0.5753 - precision: 0.9338 - recall: 0.1230 - val_loss: 1.3007 - val_accuracy: 0.6436 - val_precision: 0.9463 - val_recall: 0.2488
# Epoch 3/50
# 254/254 [==============================] - 20s 77ms/step - loss: 1.1408 - accuracy: 0.6778 - precision: 0.9262 - recall: 0.3401 - val_loss: 1.0129 - val_accuracy: 0.7036 - val_precision: 0.9199 - val_recall: 0.4307
# Epoch 4/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.9354 - accuracy: 0.7199 - precision: 0.9124 - recall: 0.4735 - val_loss: 0.8992 - val_accuracy: 0.7127 - val_precision: 0.9089 - val_recall: 0.4873
# Epoch 5/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.7967 - accuracy: 0.7547 - precision: 0.9074 - recall: 0.5628 - val_loss: 0.7807 - val_accuracy: 0.7463 - val_precision: 0.8895 - val_recall: 0.5758
# Epoch 6/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.7068 - accuracy: 0.7753 - precision: 0.9002 - recall: 0.6182 - val_loss: 0.6867 - val_accuracy: 0.7706 - val_precision: 0.8880 - val_recall: 0.6370
# Epoch 7/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.6257 - accuracy: 0.8017 - precision: 0.9117 - recall: 0.6708 - val_loss: 0.6301 - val_accuracy: 0.7940 - val_precision: 0.9018 - val_recall: 0.6731
# Epoch 8/50
# 254/254 [==============================] - 20s 78ms/step - loss: 0.5860 - accuracy: 0.8086 - precision: 0.9076 - recall: 0.6904 - val_loss: 0.5955 - val_accuracy: 0.7934 - val_precision: 0.9003 - val_recall: 0.6725
# Epoch 9/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.5281 - accuracy: 0.8255 - precision: 0.9138 - recall: 0.7223 - val_loss: 0.5479 - val_accuracy: 0.8191 - val_precision: 0.9086 - val_recall: 0.7217
# Epoch 10/50
# 254/254 [==============================] - 19s 76ms/step - loss: 0.5001 - accuracy: 0.8367 - precision: 0.9185 - recall: 0.7442 - val_loss: 0.5459 - val_accuracy: 0.8068 - val_precision: 0.8870 - val_recall: 0.7204
# Epoch 11/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.4673 - accuracy: 0.8462 - precision: 0.9194 - recall: 0.7634 - val_loss: 0.4722 - val_accuracy: 0.8331 - val_precision: 0.9143 - val_recall: 0.7586
# Epoch 12/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.4215 - accuracy: 0.8608 - precision: 0.9255 - recall: 0.7872 - val_loss: 0.4465 - val_accuracy: 0.8514 - val_precision: 0.9212 - val_recall: 0.7692
# Epoch 13/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.4071 - accuracy: 0.8692 - precision: 0.9302 - recall: 0.7997 - val_loss: 0.4787 - val_accuracy: 0.8419 - val_precision: 0.8962 - val_recall: 0.7673
# Epoch 14/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.3810 - accuracy: 0.8739 - precision: 0.9298 - recall: 0.8147 - val_loss: 0.4243 - val_accuracy: 0.8530 - val_precision: 0.8989 - val_recall: 0.7929
# Epoch 15/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.3679 - accuracy: 0.8790 - precision: 0.9300 - recall: 0.8221 - val_loss: 0.3986 - val_accuracy: 0.8578 - val_precision: 0.9105 - val_recall: 0.8068
# Epoch 16/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.3363 - accuracy: 0.8899 - precision: 0.9335 - recall: 0.8409 - val_loss: 0.3688 - val_accuracy: 0.8736 - val_precision: 0.9189 - val_recall: 0.8242
# Epoch 17/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.3212 - accuracy: 0.8966 - precision: 0.9392 - recall: 0.8484 - val_loss: 0.3791 - val_accuracy: 0.8687 - val_precision: 0.9187 - val_recall: 0.8148
# Epoch 18/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.3076 - accuracy: 0.9016 - precision: 0.9400 - recall: 0.8584 - val_loss: 0.3436 - val_accuracy: 0.8872 - val_precision: 0.9276 - val_recall: 0.8460
# Epoch 19/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.2841 - accuracy: 0.9106 - precision: 0.9454 - recall: 0.8710 - val_loss: 0.3159 - val_accuracy: 0.8968 - val_precision: 0.9311 - val_recall: 0.8581
# Epoch 20/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.2891 - accuracy: 0.9060 - precision: 0.9406 - recall: 0.8677 - val_loss: 0.3703 - val_accuracy: 0.8701 - val_precision: 0.9131 - val_recall: 0.8201
# Epoch 21/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.2865 - accuracy: 0.9087 - precision: 0.9425 - recall: 0.8696 - val_loss: 0.3256 - val_accuracy: 0.8867 - val_precision: 0.9219 - val_recall: 0.8473
# Epoch 22/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.2787 - accuracy: 0.9077 - precision: 0.9398 - recall: 0.8722 - val_loss: 0.3231 - val_accuracy: 0.8909 - val_precision: 0.9225 - val_recall: 0.8591
# Epoch 23/50
# 254/254 [==============================] - 19s 77ms/step - loss: 0.2524 - accuracy: 0.9176 - precision: 0.9458 - recall: 0.8870 - val_loss: 0.2955 - val_accuracy: 0.9051 - val_precision: 0.9375 - val_recall: 0.8720
# Epoch 24/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.2506 - accuracy: 0.9207 - precision: 0.9468 - recall: 0.8906 - val_loss: 0.2780 - val_accuracy: 0.9102 - val_precision: 0.9362 - val_recall: 0.8844
# Epoch 25/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.2609 - accuracy: 0.9161 - precision: 0.9436 - recall: 0.8845 - val_loss: 0.3255 - val_accuracy: 0.8852 - val_precision: 0.9161 - val_recall: 0.8513
# Epoch 26/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.2594 - accuracy: 0.9158 - precision: 0.9443 - recall: 0.8844 - val_loss: 0.3306 - val_accuracy: 0.8857 - val_precision: 0.9200 - val_recall: 0.8489
# Epoch 27/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.2482 - accuracy: 0.9212 - precision: 0.9488 - recall: 0.8921 - val_loss: 0.2606 - val_accuracy: 0.9163 - val_precision: 0.9411 - val_recall: 0.8863
# Epoch 28/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.2196 - accuracy: 0.9304 - precision: 0.9537 - recall: 0.9035 - val_loss: 0.2683 - val_accuracy: 0.9153 - val_precision: 0.9425 - val_recall: 0.8859
# Epoch 29/50
# 254/254 [==============================] - 19s 77ms/step - loss: 0.2115 - accuracy: 0.9340 - precision: 0.9556 - recall: 0.9102 - val_loss: 0.2563 - val_accuracy: 0.9129 - val_precision: 0.9356 - val_recall: 0.8887
# Epoch 30/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.2096 - accuracy: 0.9343 - precision: 0.9552 - recall: 0.9118 - val_loss: 0.2693 - val_accuracy: 0.9136 - val_precision: 0.9363 - val_recall: 0.8870
# Epoch 31/50
# 254/254 [==============================] - 20s 77ms/step - loss: 0.1977 - accuracy: 0.9377 - precision: 0.9561 - recall: 0.9162 - val_loss: 0.2349 - val_accuracy: 0.9222 - val_precision: 0.9430 - val_recall: 0.8989
# Epoch 32/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1925 - accuracy: 0.9392 - precision: 0.9576 - recall: 0.9198 - val_loss: 0.2481 - val_accuracy: 0.9126 - val_precision: 0.9321 - val_recall: 0.8910
# Epoch 33/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1894 - accuracy: 0.9404 - precision: 0.9581 - recall: 0.9220 - val_loss: 0.2191 - val_accuracy: 0.9338 - val_precision: 0.9499 - val_recall: 0.9162
# Epoch 34/50
# 254/254 [==============================] - 20s 80ms/step - loss: 0.1792 - accuracy: 0.9436 - precision: 0.9604 - recall: 0.9264 - val_loss: 0.2225 - val_accuracy: 0.9270 - val_precision: 0.9429 - val_recall: 0.9094
# Epoch 35/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1668 - accuracy: 0.9483 - precision: 0.9629 - recall: 0.9339 - val_loss: 0.2105 - val_accuracy: 0.9275 - val_precision: 0.9462 - val_recall: 0.9106
# Epoch 36/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1699 - accuracy: 0.9464 - precision: 0.9620 - recall: 0.9303 - val_loss: 0.1983 - val_accuracy: 0.9385 - val_precision: 0.9527 - val_recall: 0.9225
# Epoch 37/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1603 - accuracy: 0.9502 - precision: 0.9636 - recall: 0.9353 - val_loss: 0.2013 - val_accuracy: 0.9375 - val_precision: 0.9522 - val_recall: 0.9187
# Epoch 38/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1604 - accuracy: 0.9507 - precision: 0.9634 - recall: 0.9370 - val_loss: 0.2350 - val_accuracy: 0.9195 - val_precision: 0.9348 - val_recall: 0.9046
# Epoch 39/50
# 254/254 [==============================] - 20s 78ms/step - loss: 0.1596 - accuracy: 0.9506 - precision: 0.9633 - recall: 0.9372 - val_loss: 0.2010 - val_accuracy: 0.9324 - val_precision: 0.9488 - val_recall: 0.9163
# Epoch 40/50
# 254/254 [==============================] - 20s 80ms/step - loss: 0.1684 - accuracy: 0.9458 - precision: 0.9597 - recall: 0.9323 - val_loss: 0.2076 - val_accuracy: 0.9312 - val_precision: 0.9445 - val_recall: 0.9175
# Epoch 41/50
# 254/254 [==============================] - 20s 80ms/step - loss: 0.1611 - accuracy: 0.9488 - precision: 0.9617 - recall: 0.9355 - val_loss: 0.2185 - val_accuracy: 0.9322 - val_precision: 0.9518 - val_recall: 0.9133
# Epoch 42/50
# 254/254 [==============================] - 20s 78ms/step - loss: 0.1682 - accuracy: 0.9458 - precision: 0.9593 - recall: 0.9330 - val_loss: 0.2165 - val_accuracy: 0.9314 - val_precision: 0.9486 - val_recall: 0.9168
# Epoch 43/50
# 254/254 [==============================] - 20s 80ms/step - loss: 0.1420 - accuracy: 0.9565 - precision: 0.9672 - recall: 0.9447 - val_loss: 0.2005 - val_accuracy: 0.9350 - val_precision: 0.9468 - val_recall: 0.9215
# Epoch 44/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1455 - accuracy: 0.9548 - precision: 0.9671 - recall: 0.9428 - val_loss: 0.1772 - val_accuracy: 0.9443 - val_precision: 0.9561 - val_recall: 0.9320
# Epoch 45/50
# 254/254 [==============================] - 20s 78ms/step - loss: 0.1310 - accuracy: 0.9607 - precision: 0.9708 - recall: 0.9503 - val_loss: 0.1904 - val_accuracy: 0.9384 - val_precision: 0.9513 - val_recall: 0.9261
# Epoch 46/50
# 254/254 [==============================] - 20s 79ms/step - loss: 0.1305 - accuracy: 0.9600 - precision: 0.9697 - recall: 0.9503 - val_loss: 0.1678 - val_accuracy: 0.9467 - val_precision: 0.9576 - val_recall: 0.9349
# Epoch 47/50
# 254/254 [==============================] - 20s 80ms/step - loss: 0.1228 - accuracy: 0.9629 - precision: 0.9719 - recall: 0.9535 - val_loss: 0.2265 - val_accuracy: 0.9272 - val_precision: 0.9432 - val_recall: 0.9141
# Epoch 48/50
# 254/254 [==============================] - 20s 78ms/step - loss: 0.1423 - accuracy: 0.9564 - precision: 0.9660 - recall: 0.9458 - val_loss: 0.1931 - val_accuracy: 0.9390 - val_precision: 0.9519 - val_recall: 0.9247
# Epoch 49/50
# 254/254 [==============================] - 20s 80ms/step - loss: 0.1220 - accuracy: 0.9622 - precision: 0.9712 - recall: 0.9539 - val_loss: 0.1690 - val_accuracy: 0.9437 - val_precision: 0.9548 - val_recall: 0.9303
# Epoch 50/50
# 254/254 [==============================] - 21s 81ms/step - loss: 0.1144 - accuracy: 0.9650 - precision: 0.9730 - recall: 0.9572 - val_loss: 0.1592 - val_accuracy: 0.9520 - val_precision: 0.9599 - val_recall: 0.9440

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150, 64)           19456
#
#  dense (Dense)               (None, 150, 40)           2600
#
# =================================================================
# Total params: 22,056
# Trainable params: 22,056
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model.evaluate(X_test, y_test)
print("Test loss:", results[0])
print("Test accuracy:", results[1])
print("Test precision:", results[2])
print("Test recall:", results[3])
# Out:
# 32/32 [==============================] - 1s 34ms/step - loss: 0.1646 - accuracy: 0.9439 - precision: 0.9534 - recall: 0.9349
# Test loss: 0.16463488340377808
# Test accuracy: 0.943893313407898
# Test precision: 0.9534328579902649
# Test recall: 0.9348599910736084

# %%
plt.figure(figsize=(16, 16))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(16, 16))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
model.save('../models/all.h5')

# %%
y_pred = model.predict(X_test)
predictions = np.argmax(y_pred, axis=2)
print(predictions)
major = mode(predictions, axis=1)[0].squeeze()
count = mode(predictions, axis=1)[1].squeeze()
print(f"Predictions    : {major}")
print(f"Appeared times : {count}")
# Out:
# 2023-04-14 04:04:17.672005: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-14 04:04:17.674905: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-14 04:04:17.677284: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 32/32 [==============================] - 2s 27ms/step
# [[39 39 39 ... 39 39 39]
#  [10  2  2 ...  2  2  2]
#  [19 21 21 ... 21 21 21]
#  ...
#  [ 8 31 31 ... 31 31 31]
#  [13 13 13 ... 13 13 13]
#  [18 18 18 ... 18 18 18]]
# Predictions    : [39  2 21 13 19 13 27  0 14  4 29  2 12  7 31  4 28 10 39 24 37 36 36  2
#  23  8 14 36 30  6  8 22 34 23  8 21 11 39 25 35 13  4 14  5 18  4  1 20
#  26 38 19  2 30 19 35 10 35  7 23 30 11 14 12 17 18 28 29 24 35 12 19 31
#  25 16 19 27 27  2 27  3 39 24 24 39 20 13 17 32 32 27 35 13  4 39 29 28
#  11 34 10  4 14 33 17 16  6 26 20 39  8 13  8 13  0  8 38 28  6 14 13 12
#   1 33 29 25 24 37 30 15 13  6 37  8 18 30 28 33 16  2  5 31 18 30 18  4
#   2  4 34 20 23 13  0  4 33  6  9 16 17  4 12 11  3 32 38 10  9 17  6 16
#  23 35 30 32 39 11 14 38 34 26 18  5  5 38 17 37 36 10 34  4 16  5  0  7
#  150 150 149 115 150 150 150 150 150 150 150 103 150 150 149 150 150 150
#  150 150 150 150 149 150 150 150 148 150 143 150 150 144 150  75 149 150
#  150 111 150 150 118 149 150 150 150 150 150 150 150 150 149 149 150 141
#  144 147 149 146 150 149 147 150 150 149 150 150 150 150 149 150 150 148
#  145 116 150 150 150 150 150 150 150 150 149 148 150 150 121 149 150 149
#  150 146 150 150 150 150 150 143 147 149 146 150 150 148 150 150 150 146
#  150 145 129 150 148 150 150 150 149 146 150 150 150 150 150 150 149 150
#   77 138 150 150 150 104 149 150 150 145 150 150 148 150 150 148 150 101
#  150 150 136 149 150 150 111 149 146 139 150 150 150 148 150 150 150 148
#  150 150 150  95 150 148 150 138 142 149 150 150 150 150 150 150 150 150
#  150 150 147 150 150 150 148 148 150 150 150 102 149 100 150 150 150 150
#  148 149 150 149 150 148 150 130 150 150 150 150 149 150 118 149 150 150
#  148  90 150 134 150 104 149 147 150 150 150 150 149 150 150 134 150 150
#  150 150 150 150 150 150 150 138 150 150 150 150 150 150 150 141 150 149
#  137 150 126 150 150 150 139 149 149 149 150 150 150 100 150 123 150 150
#  150 150 150 150 150 148 150 150 132 150 150 144 150 150 150 149 150 150
#  149 150 150 132 150 150  92 149 150 150]
# /tmp/ipykernel_36639/310183563.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   major = mode(predictions, axis=1)[0].squeeze()
# /tmp/ipykernel_36639/310183563.py:5: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   count = mode(predictions, axis=1)[1].squeeze()

# %%
def get_key(dictionary, val):
    for key, value in dictionary.items():
        if val == value:
            return key

predictions_list = []
for word in major:
    predictions_list.append(get_key(label_dict, word))
print(predictions_list)
# Out:
# ['z', 'bad', 'n', 'hello', 'm', 'hello', 'r', 'a', 'hungry', 'd', 'sorry', 'bad', 'h', 'f', 'thankyou', 'd', 's', 'good', 'z', 'p', 'yes', 'y', 'y', 'bad', 'o', 'fine', 'hungry', 'y', 't', 'e', 'fine', 'no', 'w', 'o', 'fine', 'n', 'goodbye', 'z', 'please', 'x', 'hello', 'd', 'hungry', 'deaf', 'l', 'd', 'b', 'me', 'q', 'you', 'm', 'bad', 't', 'm', 'x', 'good', 'x', 'f', 'o', 't', 'goodbye', 'hungry', 'h', 'k', 'l', 's', 'sorry', 'p', 'x', 'h', 'm', 'thankyou', 'please', 'j', 'm', 'r', 'r', 'bad', 'r', 'c', 'z', 'p', 'p', 'z', 'me', 'hello', 'k', 'u', 'u', 'r', 'x', 'hello', 'd', 'z', 'sorry', 's', 'goodbye', 'w', 'good', 'd', 'hungry', 'v', 'k', 'j', 'e', 'q', 'me', 'z', 'fine', 'hello', 'fine', 'hello', 'a', 'fine', 'you', 's', 'e', 'hungry', 'hello', 'h', 'b', 'v', 'sorry', 'please', 'p', 'yes', 't', 'i', 'hello', 'e', 'yes', 'fine', 'l', 't', 's', 'v', 'j', 'bad', 'deaf', 'thankyou', 'l', 't', 'l', 'd', 'bad', 'd', 'w', 'me', 'o', 'hello', 'a', 'd', 'v', 'e', 'g', 'j', 'k', 'd', 'h', 'goodbye', 'c', 'u', 'you', 'good', 'g', 'k', 'e', 'j', 'o', 'x', 't', 'u', 'z', 'goodbye', 'hung
'a', 't', 'y', 'you', 'b', 'r', 'x', 'bad', 'bad', 'q', 'v', 'd', 'yes', 'x', 's', 'sorry', 'deaf', 's', 'c', 'no', 'd', 'hello', 'no', 'hungry', 'please', 'hello', 'l', 'no', 'yes', 'h', 'you', 'w', 'o', 'o', 'q', 'p', 'x', 'please', 'n', 'o', 'w', 'b', 'g', 'no', 'a', 'l', 'me', 'me', 'p', 'l', 'you', 'f', 'l', 'n', 'p', 'z', 'y', 'me', 'n', 't', 'fine', 'a', 'me', 'o', 'hello', 'k', 'q', 'm', 'me', 'f', 'w', 'g', 'deaf', 'no', 'w', 'n', 'n', 'k', 'r', 'u', 'f', 'deaf', 'hello', 'v', 'l', 'z', 'n', 'j', 't', 'you', 'fine', 'y', 'bad', 'n', 's', 'o', 'y', 'you', 'd', 'yes', 'hungry', 'c', 'x', 'n', 'me', 'hello', 'me', 'good', 'hungry', 'c', 'd ...

# %%
words_cm = confusion_matrix(y_test.argmax(axis=2).flatten(), y_pred.argmax(axis=2).flatten())
plt.subplots(figsize=(16, 16))
sns.heatmap(words_cm, annot=True, cmap='Blues', fmt='g', xticklabels=label_dict.keys(), yticklabels=label_dict.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
accuracy = np.sum(np.diag(words_cm)) / np.sum(words_cm)
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Accuracy: 94.39%

# %%
print(classification_report(y_test.argmax(axis=2).flatten(), y_pred.argmax(axis=2).flatten()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      4800
#            1       1.00      0.99      1.00      3450
#            2       0.87      0.83      0.85      4500
#            3       0.97      0.89      0.93      3750
#            4       0.97      0.91      0.94      3750
#            5       0.97      0.89      0.93      4200
#            6       0.89      0.83      0.86      3300
#            7       1.00      1.00      1.00      3300
#            8       0.99      0.99      0.99      4050
#            9       0.98      1.00      0.99      2850
#           10       0.79      0.83      0.81      3600
#           11       0.99      0.98      0.98      3000
#           12       1.00      1.00      1.00      3150
#           13       0.99      0.99      0.99      4500
#           14       1.00      0.97      0.99      4800
#           15       0.94      0.97      0.95      3300
#           16       0.98      0.93      0.95      3000
#           17       0.99      0.96      0.97      5700
#           18       0.95      1.00      0.98      4500
#           19       1.00      1.00      1.00      3000
#           20       0.89      0.93      0.91      4050
#           21       1.00      0.95      0.98      4050
#           22       0.98      0.97      0.98      3900
#           23       0.89      0.94      0.91      3750
#           24       0.94      1.00      0.97      2550
#           25       0.98      0.99      0.99      3000
#           26       1.00      1.00      1.00      3600
#           27       0.93      0.99      0.96      3450
#           28       0.75      0.98      0.85      2850
#           29       0.98      1.00      0.99      3300
#           30       0.99      0.95      0.97      4050
#           31       0.91      0.90      0.91      3900
#           32       0.70      0.88      0.78      3450
#           33       0.90      0.76      0.82      5100
#           34       1.00      1.00      1.00      3450
#           35       0.91      0.98      0.95      4500
#           36       0.99      1.00      0.99      2550
#           37       0.94      0.91      0.93      3900
#           38       0.93      0.93      0.93      4350
#           39       0.95      0.97      0.96      3750
#
#     accuracy                           0.94    150000
#    macro avg       0.95      0.95      0.95    150000
# weighted avg       0.95      0.94      0.94    150000

# %%
engine = pyttsx3.init()
engine.say(", ".join(predictions_list))
engine.runAndWait()
